# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
filepath = 'C:/Users/User/Desktop/Master/Multivariational Analysis/MV.xlsx'

# %%
df = pd.read_excel(filepath, index_col='Country')

# %%
top_gdp_df = df.nlargest(10, 'GDP')

plt.bar(top_gdp_df.index, top_gdp_df['GDP'])
plt.xlabel('Земја')
plt.ylabel('БДП По Глава На Жител')
plt.title('10-те Земји Со Највисок БДП По Глава На Жител 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
least_gdp_df = df.nsmallest(10, 'GDP')

plt.bar(least_gdp_df.index, least_gdp_df['GDP'])
plt.xlabel('Земја')
plt.ylabel('БДП По Глава На Жител')
plt.title('10-те Земји Со Најнизок БДП По Глава На Жител 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_trade_df = df.nlargest(10, 'TRD')

plt.bar(top_trade_df.index, top_trade_df['TRD'])
plt.xlabel('Земја')
plt.ylabel('Обем На Трговија')
plt.title('10-те Земји Со Највисок Обем На Трговија 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
least_trade_df = df.nsmallest(10, 'TRD')

plt.bar(least_trade_df.index, least_trade_df['TRD'])
plt.xlabel('Земја')
plt.ylabel('Обем На Трговија')
plt.title('10-те Земји Со Најнизок Обем На Трговија 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_unemployment_df = df.nlargest(10, 'UNMP')

plt.bar(top_unemployment_df.index, top_unemployment_df['UNMP'])
plt.xlabel('Земја')
plt.ylabel('Стапка На Невработеност')
plt.title('10-те Земји Со Најголема Стапка На Невработеност 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
least_unemployment_df = df.nsmallest(10, 'UNMP')

plt.bar(least_unemployment_df.index, least_unemployment_df['UNMP'])
plt.xlabel('Земја')
plt.ylabel('Стапка На Невработеност')
plt.title('10-те Земји Со Најниска Стапка На Невработеност 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_exp_df = df.nlargest(10, 'EXP')

plt.bar(top_exp_df.index, top_exp_df['EXP'])
plt.xlabel('Земја')
plt.ylabel('Потрошувачка Како % Од БДП')
plt.title('10-те Земји Со Најголема Потрошувачка Како % Од БДП 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
least_exp_df = df.nsmallest(10, 'EXP')

plt.bar(least_exp_df.index, least_exp_df['EXP'])
plt.xlabel('Земја')
plt.ylabel('Потрошувачка Како % Од БДП')
plt.title('10-те Земји Со Најмала Потрошувачка Како % Од БДП 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_hicp_df = df.nlargest(10, 'HICP')

plt.bar(top_hicp_df.index, top_hicp_df['HICP'])
plt.xlabel('Земја')
plt.ylabel('HICP')
plt.title('10-те Земји Со Најголема Стапка На HICP 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
least_hicp_df = df.nsmallest(10, 'HICP')

plt.bar(least_hicp_df.index, least_hicp_df['HICP'])
plt.xlabel('Земја')
plt.ylabel('HICP')
plt.title('10-те Земји Со Најниска Стапка На HICP 2023')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
gdp_mean = df['GDP'].mean()
gdp_var = df['GDP'].var()
gdp_max = df['GDP'].max()
gdp_min = df['GDP'].min()
gdp_median = df['GDP'].median()
gdp_skew = df['GDP'].skew()
gdp_kurtosis = df['GDP'].kurtosis()

# %%
gdp_stats = {
    'Statistic': ['Mean', 'Variance', 'Max', 'Min', 'Median', 'Skewness', 'Kurtosis'],
    'Value': [gdp_mean, gdp_var, gdp_max, gdp_min, gdp_median, gdp_skew, gdp_kurtosis]
}
gdp_df = pd.DataFrame(gdp_stats)

# %%
trade_mean = df['TRD'].mean()
trade_var = df['TRD'].var()
trade_max = df['TRD'].max()
trade_min = df['TRD'].min()
trade_median = df['TRD'].median()
trade_skew = df['TRD'].skew()
trade_kurtosis = df['TRD'].kurtosis()

# %%
trade_stats = {
    'Statistic': ['Mean', 'Variance', 'Max', 'Min', 'Median', 'Skewness', 'Kurtosis'],
    'Value': [trade_mean, trade_var, trade_max, trade_min, trade_median, trade_skew, trade_kurtosis]
}
trade_df = pd.DataFrame(trade_stats)

# %%
unemployment_mean = df['UNMP'].mean()
unemployment_var = df['UNMP'].var()
unemployment_max = df['UNMP'].max()
unemployment_min = df['UNMP'].min()
unemployment_median = df['UNMP'].median()
unemployment_skew = df['UNMP'].skew()
unemployment_kurtosis = df['UNMP'].kurtosis()

# %%
unemployment_stats = {
    'Statistic': ['Mean', 'Variance', 'Max', 'Min', 'Median', 'Skewness', 'Kurtosis'],
    'Value': [unemployment_mean, unemployment_var, unemployment_max, unemployment_min, unemployment_median, unemployment_skew, unemployment_kurtosis]
}
unemployment_df = pd.DataFrame(unemployment_stats)

# %%
exp_mean = df['EXP'].mean()
exp_var = df['EXP'].var()
exp_max = df['EXP'].max()
exp_min = df['EXP'].min()
exp_median = df['EXP'].median()
exp_skew = df['EXP'].skew()
exp_kurtosis = df['EXP'].kurtosis()

# %%
exp_stats = {
    'Statistic': ['Mean', 'Variance', 'Max', 'Min', 'Median', 'Skewness', 'Kurtosis'],
    'Value': [exp_mean, exp_var, exp_max, exp_min, exp_median, exp_skew, exp_kurtosis]
}
exp_df = pd.DataFrame(exp_stats)

# %%
hicp_mean = df['HICP'].mean()
hicp_var = df['HICP'].var()
hicp_max = df['HICP'].max()
hicp_min = df['HICP'].min()
hicp_median = df['HICP'].median()
hicp_skew = df['HICP'].skew()
hicp_kurtosis = df['HICP'].kurtosis()

# %%
hicp_stats = {
    'Statistic': ['Mean', 'Variance', 'Max', 'Min', 'Median', 'Skewness', 'Kurtosis'],
    'Value': [hicp_mean, hicp_var, hicp_max, hicp_min, hicp_median, hicp_skew, hicp_kurtosis]
}
hicp_df = pd.DataFrame(hicp_stats)

# %%
means = df[['GDP', 'EXP', 'UNMP', 'TRD', 'HICP']].mean()
std_devs = df[['GDP', 'EXP', 'UNMP', 'TRD', 'HICP']].std()

# %%
differences = df[['GDP', 'EXP', 'UNMP', 'TRD', 'HICP']] - means
squared_diff = differences**2
outliers = (differences.abs() > (3 * std_devs))
print(outliers)
# Out:
#                GDP    EXP   UNMP    TRD   HICP
# Country
# Белгија      False  False  False  False  False
# Бугарија     False  False  False  False  False
# Чешка        False  False  False  False  False
# Данска       False  False  False  False  False
# Германија    False  False  False   True  False
# Естонија     False  False  False  False  False
# Ирска        False   True  False  False  False
# Грција       False  False  False  False  False
# Шпанија      False  False  False  False  False
# Франција     False  False  False  False  False
# Хрватска     False  False  False  False  False
# Италија      False  False  False  False  False
# Кипар        False  False  False  False  False
# Латвија      False  False  False  False  False
# Литванија    False  False  False  False  False
# Луксембург   False  False  False  False  False
# Унгарија     False  False  False  False   True
# Малта        False  False  False  False  False
# Холандија    False  False  False  False  False
# ...

# %%
sns.boxplot(data=df[['HICP', 'EXP']])
plt.title("Екстремни Вредности при HICP и EXP")
plt.show()

# %%
sns.boxplot(data=df[['TRD']])
plt.title("Екстремни Вредности при TRD")
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
linkage_matrix = linkage(df_scaled, method='ward')

# %%
plt.figure(figsize=(12, 8))
dendrogram(
    linkage_matrix,
    labels=df.index.tolist(),
    leaf_rotation=90,
    leaf_font_size=10
)
plt.title('Хиерархиски Дендрограм')
plt.xlabel('Земја')
plt.ylabel('Дистанца')
plt.show()

# %%
clusters = fcluster(linkage_matrix, t=3, criterion='maxclust')
df['Cluster'] = clusters
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 2    15
# 1     9
# 3     3
# Name: count, dtype: int64

# %%
clusters_grouped_df = (df.groupby('Cluster').mean())
print(clusters_grouped_df)
# Out:
#                   GDP            TRD        EXP      HICP      UNMP
# Cluster
# 1        40250.000000  -16960.044444  50.988889  4.222222  7.666667
# 2        18410.666667   -4282.926667  43.940000  8.946667  5.046667
# 3        50816.666667  120804.633333  38.100000  5.100000  3.666667
